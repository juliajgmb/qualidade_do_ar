# %% [markdown]
# ## Carregando dados

# %%
import pandas as pd

# %%
dados = pd.read_csv(r"C:\Users\gabri\OneDrive\Documentos\projetos\air+quality\AirQualityUCI.csv", sep=';')

# %%
dados.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# ...

# %%
dados.rename(columns={
    'CO(GT)': 'Monóxido de Carbono (CO)',
    'PT08.S1(CO)': 'Óxidos de Carbono (Sensor 1)',
    'NMHC(GT)': 'Hidrocarbonetos Não-Metanicos (NMHC)',
    'C6H6(GT)': 'Benzeno (C6H6)',
    'PT08.S2(NMHC)': 'Hidrocarbonetos (Sensor 2)',
    'NOx(GT)': 'Óxidos de Nitrogênio (NOx)',
    'PT08.S3(NOx)': 'Óxidos de Nitrogênio (Sensor 3)',
    'NO2(GT)': 'Dióxido de Nitrogênio (NO2)',
    'PT08.S4(NO2)': 'Dióxido de Nitrogênio (Sensor 4)',
    'PT08.S5(O3)': 'Ozônio (Sensor 5)',
    'T': 'Temperatura (C)',
    'RH': 'Umidade Relativa (%)',
    'AH': 'Umidade Absoluta (g/m³)'
}, inplace=True)

dados.drop(columns=['Unnamed: 15', 'Unnamed: 16'], inplace=True)

dados.head()
# Out:
#          Date      Time Monóxido de Carbono (CO)  \
# 0  10/03/2004  18.00.00                      2,6
# 1  10/03/2004  19.00.00                        2
# 2  10/03/2004  20.00.00                      2,2
# 3  10/03/2004  21.00.00                      2,2
# 4  10/03/2004  22.00.00                      1,6
#
#    Óxidos de Carbono (Sensor 1)  Hidrocarbonetos Não-Metanicos (NMHC)  \
# 0                        1360.0                                 150.0
# 1                        1292.0                                 112.0
# 2                        1402.0                                  88.0
# 3                        1376.0                                  80.0
# 4                        1272.0                                  51.0
#
#   Benzeno (C6H6)  Hidrocarbonetos (Sensor 2)  Óxidos de Nitrogênio (NOx)  \
# 0           11,9                      1046.0                       166.0
# 1            9,4                       955.0                       103.0
# ...
